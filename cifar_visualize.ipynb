# %%
# %matplotlib inline
from data import cifar_view

# %%
cifar10_batch_1 = './data/cifar10/data_batch_1'
cifar100_batch = './data/cifar100/train'

# %%
view_cifar10(cifar10_batch_1)
# Out:
# ['cat', 'airplane', 'cat', 'horse', 'dog']
# ['deer', 'frog', 'airplane', 'airplane', 'automobile']
# ['ship', 'bird', 'deer', 'cat', 'bird']
# ['ship', 'ship', 'bird', 'deer', 'deer']
# ['airplane', 'cat', 'bird', 'bird', 'dog']

# %%
view_cifar100(cifar100_batch)
# Out:
# ['crocodile', 'table', 'snake', 'leopard', 'crab']
# ['trout', 'mouse', 'shark', 'maple_tree', 'aquarium_fish']
# ['fox', 'pickup_truck', 'sunflower', 'bear', 'shrew']
# ['house', 'bee', 'snake', 'man', 'pear']
# ['sunflower', 'table', 'crab', 'hamster', 'shrew']

# %%
view_cifar100(cifar100_batch, True, 49999)
# Out:
# shark

# %%
view_cifar10(cifar10_batch_1, True, 5000)
# Out:
# frog
